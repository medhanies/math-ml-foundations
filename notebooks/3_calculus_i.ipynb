# %% [markdown]
# <a href="https://colab.research.google.com/github/medhanies/math-ml-foundations/blob/main/notebooks/3_calculus_i.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Calculus 1: Limits and Derivatives

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 1000) # start, finish, n points

# %%
y = x**2 + 2*x + 2

# %%
fig, ax = plt.subplots()
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-2, -0])
ax.set_ylim([0, 2])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.5, -0.5])
ax.set_ylim([0.5, 1.5])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.1, -0.9])
ax.set_ylim([0.9, 1.1])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.01, -0.99])
ax.set_ylim([0.99, 1.01])
_ = ax.plot(x,y)

# %% [markdown]
# **Limits**

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-5, 10)
plt.ylim(-10, 80)
plt.axvline(x=5, color='purple', linestyle='--')
plt.axhline(y=37, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$\lim_{x \to 1} \frac{x^2 - 1}{x - 1}$$

# %%
def my_fxn(my_x):
  my_y = (my_x**2 - 1)/(my_x - 1)
  return my_y

# %%
my_fxn(2)
# Out:
# 3.0

# %%
my_fxn(0.9)
# Out:
# 1.9

# %%
my_fxn(0.999)
# Out:
# 1.9989999999999712

# %%
my_fxn(1.1)
# Out:
# 2.1

# %%
my_fxn(1.001)
# Out:
# 2.0009999999999177

# %% [markdown]
# $$\lim_{x \to 0} \frac{\text{sin } x}{x}$$

# %%
def sin_fxn(my_x):
  my_y = np.sin(my_x)/my_x
  return my_y

# %%
sin_fxn(0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(0.001)
# Out:
# 0.9999998333333416

# %%
sin_fxn(-0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(-0.001)
# Out:
# 0.9999998333333416

# %%
y = sin_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-1, 2)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=1, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$ \lim_{x \to \infty} \frac{25}{x} $$

# %%
def inf_fxn(my_x):
  my_y = 25/my_x
  return my_y

# %%
inf_fxn(1e3)
# Out:
# 0.025

# %%
inf_fxn(1e6)
# Out:
# 2.5e-05

# %%
y = inf_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=1, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %%
left_x = x[x<0]
right_x = x[x>0]

# %%
left_y = inf_fxn(left_x)
right_y = inf_fxn(right_x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
ax.plot(left_x, left_y, c='C0')
_ = ax.plot(right_x, right_y, c='C0')

# %% [markdown]
# **Exercises:**
#
# Evaluate the limits below using techniques from the slides or above.
#
# 1. $$ \lim_{x \to 0} \frac{x^2-1}{x-1} $$
# 2. $$ \lim_{x \to -5} \frac{x^2-25}{x+5} $$
# 3. $$ \lim_{x \to 4} \frac{x^2 -2x -8}{x-4} $$
# 4. $$ \lim_{x \to -\infty} \frac{25}{x} $$
# 5. $$ \lim_{x \to 0} \frac{25}{x} $$

# %%
# first problem
def fn(x):
  y = (x**2 - 1) / (x - 1)
  return y

# %%
y = ((x**2) - 1) / (x - 1)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-5, 5)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=1, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %%
fn(0)
# Out:
# 1.0

# %%
# second problem
def fn(x):
  y = (x**2 - 25) / (x+5)
  return y

# %%
y = (x**2 - 25) / (x+5)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-20, 5)
plt.axvline(x=-5, color='purple', linestyle='--')
plt.axhline(y=-10, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %%
fn(-5.0001)
# Out:
# -10.000100000008274

# %%
# third problem
def fn(x):
  y = (x**2 -2*x - 8) / (x - 4)
  return y

# %%
y = (x**2 -2*x - 8) / (x - 4)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-20, 20)
plt.axvline(x=4, color='purple', linestyle='--')
plt.axhline(y=6, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %%
fn(4.001)
# Out:
# 6.001000000001028

# %%
fn(3.999)
# Out:
# 5.999000000000748

# %%
# forth problem
def fn(x):
  y = 25 / x
  return y

# %%
y = 25 / x

# %%
fn(-5000)
# Out:
# -0.005

# %%
left_x = x[x<0]
right_x = x[x>0]

# %%
left_y = inf_fxn(left_x)
right_y = inf_fxn(right_x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
ax.plot(left_x, left_y, c='C0')
_ = ax.plot(right_x, right_y, c='C0')

# %%
# fifth problem
def fn(x):
  y = 25 / x
  return y

# %%
fn(-0.00001)
# Out:
# -2500000.0

# %%
left_x = x[x<0]
right_x = x[x>0]

# %%
left_y = inf_fxn(left_x)
right_y = inf_fxn(right_x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
ax.plot(left_x, left_y, c='C0')
_ = ax.plot(right_x, right_y, c='C0')

# %% [markdown]
# **Segment 2: Computing Derivatives with Differentiation**

# %%
def f(my_x):
  my_y = my_x**2 + 2*my_x + 2
  return my_y

# %%
y = f(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
_ = ax.plot(x,y)

# %%
f(2)
# Out:
# 10

# %%
# plot point P at (2,10)
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
_ = ax.plot(x,y)

# %%
f(5)
# Out:
# 37

# %%
# plot point Q at (5,37)
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(5, 37, c = 'orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# To find the slope $m$ between points $P$ and $Q$:
# $$m = \frac{\text{change in }y}{\text{change in }x} = \frac{\Delta y}{\Delta x} = \frac{y_2 - y_1}{x_2 - x_1} = \frac{37-10}{5-2} = \frac{27}{3} = 9$$

# %%
m = (37 - 10)/(5 - 2)
m
# Out:
# 9.0

# %% [markdown]
# b = y - mx

# %%
b = 37-m*5
b
# Out:
# -8.0

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(5, 37, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange')
_ = ax.plot(x,y)

# %%
f(2.1)
# Out:
# 10.61

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(2.1, 10.61, c='orange', zorder=3)
_ = ax.plot(x,y)

# %%
m = (10.61-10)/(2.1-2)
m
# Out:
# 6.099999999999989

# %%
b = 10.61-m*2.1
b
# Out:
# -2.199999999999978

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(2.1, 10.61, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %%
delta_x = 0.000001
delta_x
# Out:
# 1e-06

# %%
x1 = 2
y1= 10

# %%
x2 = x1 + delta_x
x2
# Out:
# 2.000001

# %%
y2 = f(x2)
y2
# Out:
# 10.000006000001001

# %%
m = (y2 - y1)/(x2 - x1)
m
# Out:
# 6.000001000088901

# %% [markdown]
# **Exercise:** Find the slope of the tangent where x = -1

# %%
f(-1)
# Out:
# 1

# %%
x1 = -1

# %%
delta_x
# Out:
# 1e-06

# %%
x2 = x1 + delta_x

# %%
y1 = f(x1)

# %%
y2 = f(x2)
y2
# Out:
# 1.000000000001

# %%
y2 = (f(x1 + delta_x))
y2
# Out:
# 1.000000000001

# %%
m = (y2-y1)/(x2-x1)
m
# Out:
# 1.0000889005535828e-06

# %%
b = y2-m*x2
b
# Out:
# 1.0000010000889006

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(x1, y1)
plt.scatter(x2, y2, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# Finally, replacing $y_1$ with $f(x)$ and replacing $y_2$ with $f(x + \Delta x)$, we obtain a common representation of differentiation:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{f(x + \Delta x) - f(x)}{\Delta x}$$

# %%
def diff_demo(my_f, my_x, my_delta):
  return (my_f(my_x + my_delta) - my_f(my_x)) / my_delta

# %%
deltas = [1, 0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001]

# %%
for delta in deltas:
  print(diff_demo(f, 2, delta))
# Out:
# 7.0
# 6.099999999999994
# 6.009999999999849
# 6.000999999999479
# 6.000100000012054
# 6.000009999951316
# 6.000001000927568

# %%
for delta in deltas:
  print(diff_demo(f, -1, delta))
# Out:
# 1.0
# 0.10000000000000009
# 0.009999999999998899
# 0.001000000000139778
# 9.99999993922529e-05
# 1.000000082740371e-05
# 1.000088900582341e-06
