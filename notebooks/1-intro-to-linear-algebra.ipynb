# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000) #start, finish, n points

# %%
#distance travelled by robber

d_r = 2.5 * t

# %%
#distance travelled by sheriff

d_s = 3 * (t-5)

# %%
# %matplotlib inline
fig, ax = plt.subplots()
plt.title('A Bank Robber Caught')
plt.xlabel('time (in minutes)')
plt.ylabel('distance (in km)')
ax.set_xlim([0,40])
ax.set_ylim([0,100])
ax.plot(t, d_r, c='green')
ax.plot(t, d_s, c='brown')
plt.axvline(x=30, color='purple', linestyle='--')
_= plt.axhline(y=75, color='purple', linestyle='--')

# %% [markdown]
# ## Scalars (Base 0 Tensors)

# %%
x = 25
x
# Out:
# 25

# %%
type(x)
# Out:
# int

# %%
y = 3

# %%
py_sum = x + y
py_sum
# Out:
# 28

# %%
type(py_sum)
# Out:
# int

# %%
x_float = 25.0
float_sum = x_float + y
float_sum
# Out:
# 28.0

# %%
type(float_sum)
# Out:
# float

# %%
import torch

# %%
x_pt = torch.tensor(25)
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %% [markdown]
# **Scalars in Tenserflow**

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=25>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(3, dtype=tf.int16)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=3>

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum.numpy()
# Out:
# 28

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %%
tf_float = tf.Variable(25, dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=25.0>

# %% [markdown]
# **Vectors**

# %%
x = np.array([25, 2, 5])
x
# Out:
# array([25,  2,  5])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0]
# Out:
# 25

# %%
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# **Vector Transposition**

# %%
# transposing a 1-D array has no affect
x_t = x.T
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
#... but it does when we use nested "matrix style" brackets:
y = np.array([[25, 2, 5]])
y
# Out:
# array([[25,  2,  5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape
# Out:
# (3, 1)

# %%
y_t.T
# Out:
# array([[25,  2,  5]])

# %%
y_t.shape
# Out:
# (3, 1)

# %% [markdown]
# **Zero Vectors**

# %%
# have no effect if added to another vector
z = np.zeros(3)
z
# Out:
# array([0., 0., 0.])

# %% [markdown]
# **Vectors in PyTorch and TensorFlow**

# %%
x_pt = torch.tensor([25, 2, 5])
x_pt
# Out:
# tensor([25,  2,  5])

# %%
x_tf = tf.Variable([25, 2, 5])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %% [markdown]
# **L2 Norm**

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5 **2)**(1/2)
# Out:
# 25.573423705088842

# %%
np.linalg.norm(x)
# Out:
# 25.573423705088842

# %% [markdown]
# so if units in this 3-D vector space are meters, then the vector x has a length of 25.6 meters

# %% [markdown]
# # L1 Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.abs(25) + np.abs(2) + np.abs(5)
# Out:
# 32

# %% [markdown]
# **Squared L2 Norm**

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)
# Out:
# 654

# %%
np.dot(x,x)
# Out:
# 654

# %% [markdown]
# **Max** **Norm**

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.max([np.abs(25), np.abs(2), np.abs(5)])
# Out:
# 25

# %% [markdown]
# **Orthogonal Vectors**

# %%
i = np.array([1,0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0,1])
j
# Out:
# array([0, 1])

# %%
np.dot(i,j)
# Out:
# 0

# %% [markdown]
# **Matrices**

# %%
# use array with nested brackets
X = np.array([[25, 2], [5, 26], [3, 7]])
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X.shape
# Out:
# (3, 2)

# %%
X.size
# Out:
# 6

# %%
X[:,0]
# Out:
# array([25,  5,  3])

# %%
X[1,:]
# Out:
# array([ 5, 26])

# %%
X[0:2, 0:2]
# Out:
# array([[25,  2],
#        [ 5, 26]])

# %%
X_pt = torch.tensor([[25, 2], [5, 26], [3, 7]])
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
X_pt[1,:]
# Out:
# tensor([ 5, 26])

# %%
X_tf = tf.Variable([[25, 2], [5, 26], [3, 7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([ 5, 26], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %% [markdown]
# **Higher Rank Tensors**

# %%
images_pt = torch.zeros([32, 28, 28, 3])
# images_pt

# %%
images_tf = tf.zeros([32, 28, 28, 3])
# images_tf

# %%
x = np.array([[42, 4, 7, 99], [-99, -3, 17, 22]])

# %%
x.T
# Out:
# array([[ 42, -99],
#        [  4,  -3],
#        [  7,  17],
#        [ 99,  22]])

# %%
x.shape
# Out:
# (2, 4)

# %%
x[1, 2]
# Out:
# 17

# %%
X = torch.tensor([[42, 4, 7, 99], [-99, -3, 17, 22]])

# %%
X
# Out:
# tensor([[ 42,   4,   7,  99],
#         [-99,  -3,  17,  22]])

# %%
X[1,2]
# Out:
# tensor(17)

# %%
X = tf.Variable([[42, 4, 7, 99], [-99, -3, 17, 22]])

# %%
tf.shape(X)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 4], dtype=int32)>

# %% [markdown]
# **Segment 2: Tensor Operations**

# %% [markdown]
# **Tensor Transposition**

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X.T
# Out:
# array([[25,  5,  3],
#        [ 2, 26,  7]])

# %%
tf.transpose(X_tf)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[25,  5,  3],
#        [ 2, 26,  7]], dtype=int32)>

# %%
X_pt.T
# Out:
# tensor([[25,  5,  3],
#         [ 2, 26,  7]])

# %% [markdown]
# **Basic Tensor Arithmetic**

# %%
X*2
# Out:
# array([[50,  4],
#        [10, 52],
#        [ 6, 14]])

# %%
X+2
# Out:
# array([[27,  4],
#        [ 7, 28],
#        [ 5,  9]])

# %%
X*2+2
# Out:
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]])

# %%
X_pt*2+2
# Out:
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])

# %%
torch.add(torch.mul(X_pt, 2), 2)
# Out:
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])

# %%
X_tf*2+2
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]], dtype=int32)>

# %%
tf.add(tf.multiply(X_tf, 2), 2)
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]], dtype=int32)>

# %% [markdown]
# **Element Wise Product**

# %%
A = X+2
A
# Out:
# array([[27,  4],
#        [ 7, 28],
#        [ 5,  9]])

# %%
A + X
# Out:
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]])

# %%
A * X
# Out:
# array([[675,   8],
#        [ 35, 728],
#        [ 15,  63]])

# %%
A_pt = X_pt + 2
A_pt
# Out:
# tensor([[27,  4],
#         [ 7, 28],
#         [ 5,  9]])

# %%
A_pt + X_pt
# Out:
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])

# %%
A_pt * X_pt
# Out:
# tensor([[675,   8],
#         [ 35, 728],
#         [ 15,  63]])

# %%
A_tf = X_tf + 2
A_tf
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[27,  4],
#        [ 7, 28],
#        [ 5,  9]], dtype=int32)>

# %%
A_tf + X_tf
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]], dtype=int32)>

# %%
A_tf * X_tf
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[675,   8],
#        [ 35, 728],
#        [ 15,  63]], dtype=int32)>

# %% [markdown]
# **Reduction**

# %%
X.sum()
# Out:
# 68

# %%
torch.sum(X_pt)
# Out:
# tensor(68)

# %%
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=68>

# %%
X.sum(axis=0) # sum all rows
# Out:
# array([33, 35])

# %%
X.sum(axis=1) # sum all columns
# Out:
# array([27, 31, 10])

# %%
torch.sum(X_pt, 0)
# Out:
# tensor([33, 35])

# %%
torch.sum(X_pt, 1)
# Out:
# tensor([27, 31, 10])

# %%
tf.reduce_sum(X_tf, 1)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([27, 31, 10], dtype=int32)>

# %% [markdown]
# **Dot Product**

# %%
x = np.array([25, 2, 5])
x
# Out:
# array([25,  2,  5])

# %%
y = np.array([0, 1, 2])
y
# Out:
# array([0, 1, 2])

# %%
25*0 + 2*1 + 5*2
# Out:
# 12

# %%
np.dot(x,y)
# Out:
# 12

# %%
y_pt = torch.tensor([0, 1, 2])
y_pt
# Out:
# tensor([0, 1, 2])

# %%
np.dot(x_pt, y_pt)
# Out:
# 12

# %%
torch.dot(torch.tensor([25, 2, 5.]), torch.tensor([0, 1, 2.]))
# Out:
# tensor(12.)

# %%
y_tf = tf.Variable([0, 1, 2])
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([0, 1, 2], dtype=int32)>

# %%
tf.reduce_sum(tf.multiply(x_tf, y_tf))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=12>

# %%
z = torch.tensor([[42, 4, 7, 99], [-99, -3, 17, 22]])
z
# Out:
# tensor([[ 42,   4,   7,  99],
#         [-99,  -3,  17,  22]])

# %%
z.T
# Out:
# tensor([[ 42, -99],
#         [  4,  -3],
#         [  7,  17],
#         [ 99,  22]])

# %%
R = torch.tensor([[25, 10], [-2, 1]])
R
# Out:
# tensor([[25, 10],
#         [-2,  1]])

# %%
S = torch.tensor([[-1, 7], [10, 8]])
S
# Out:
# tensor([[-1,  7],
#         [10,  8]])

# %%
R*S
# Out:
# tensor([[-25,  70],
#         [-20,   8]])

# %%
w = np.array([-1,2,-2])
p = np.array([5,10,0])
np.dot(w,p)
# Out:
# 15

# %%
w.T*p
# Out:
# array([-5, 20,  0])

# %% [markdown]
# **Solving Linear Systems**

# %%
x = np.linspace(-10, 10, 1000) #start finish n points

# %%
y1 = 3 * x

# %%
y2 = 1 + (5*x)/2

# %%
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y')
ax.set_xlim([0, 3])
ax.set_ylim([0, 8])
ax.plot(x, y1, c='green')
ax.plot(x, y2, c='brown')
plt.axvline(x=2, color='purple', linestyle='--')
_ = plt.axhline(y=6, color='purple', linestyle='--')

# %%
y1 = -5 + (2*x)/3

# %%
y2 = (7-2*x)/5

# %%
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y')

plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')

ax.set_xlim([-2, 10])
ax.set_ylim([-6, 4])
ax.plot(x, y1, c='green')
ax.plot(x, y2, c='brown')
plt.axvline(x=6, color='purple', linestyle='--')
_ = plt.axhline(y=-1, color='purple', linestyle='--')
